# %% [markdown]
# # Partie entraînement local - Récupération image local

# %%
import numpy as np
import json
from PIL import Image, ImageDraw
import os
import pandas as pd
pd.set_option('display.max_colwidth', None)
import matplotlib.pyplot as plt

# %%
train_image_dir = "./images"

image_paths_train = []

for i in os.listdir(train_image_dir):
    folder_path = os.path.join(train_image_dir, i)
    if i != '.DS_Store':
        image_paths_train.append(folder_path)

# %%
train_label_dir = "./masks"

label_paths_train = []

for i in os.listdir(train_label_dir):
    folder_path = os.path.join(train_label_dir, i)
    if i != '.DS_Store':
        label_paths_train.append(folder_path)

# %%
df_image_paths_train = pd.DataFrame({"Index": "", "Image_Path": image_paths_train})
df_label_paths_train = pd.DataFrame({"Index": "", "Target_Path": label_paths_train})

# %%
print(len(df_image_paths_train))# X
print(len(df_label_paths_train))# y
# Out:
# 174
# 174

# %%
index_tab = []
for el in df_image_paths_train['Image_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_image_paths_train['Index'] = index_tab

# %%
index_tab = []
for el in df_label_paths_train['Target_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_label_paths_train['Index'] = index_tab

# %%
df_train = pd.merge(df_image_paths_train, df_label_paths_train, on='Index', how='left')
df_train
# Out:
#                     Index                         Image_Path  \
# 0    aachen_000008_000019  ./images/aachen_000008_000019.png
# 1    aachen_000149_000019  ./images/aachen_000149_000019.png
# 2    aachen_000095_000019  ./images/aachen_000095_000019.png
# 3    aachen_000014_000019  ./images/aachen_000014_000019.png
# 4    aachen_000023_000019  ./images/aachen_000023_000019.png
# ..                    ...                                ...
# 169  aachen_000053_000019  ./images/aachen_000053_000019.png
# 170  aachen_000112_000019  ./images/aachen_000112_000019.png
# 171  aachen_000125_000019  ./images/aachen_000125_000019.png
# 172  aachen_000006_000019  ./images/aachen_000006_000019.png
# 173  aachen_000031_000019  ./images/aachen_000031_000019.png
#
#                           Target_Path
# 0    ./masks/aachen_000008_000019.png
# 1    ./masks/aachen_000149_000019.png
# 2    ./masks/aachen_000095_000019.png
# 3    ./masks/aachen_000014_000019.png
# 4    ./masks/aachen_000023_000019.png
# ..                                ...
# 169  ./masks/aachen_000053_000019.png
# 170  ./masks/aachen_000112_000019.png
# 171  ./masks/aachen_000125_000019.png
# 172  ./masks/aachen_000006_000019.png
# 173  ./masks/aachen_000031_000019.png
#
# [174 rows x 3 columns]

# %%
val_image_dir = "./images_val"

image_paths_val = []

for i in os.listdir(val_image_dir):
    folder_path = os.path.join(val_image_dir, i)
    if i != '.DS_Store':
        image_paths_val.append(folder_path)

# %%
val_label_dir = "./masks_val"

label_paths_val = []

for i in os.listdir(val_label_dir):
    folder_path = os.path.join(val_label_dir, i)
    if i != '.DS_Store':
        label_paths_val.append(folder_path)

# %%
df_image_paths_val = pd.DataFrame({"Index": "", "Image_Path": image_paths_val})
df_label_paths_val = pd.DataFrame({"Index": "", "Target_Path": label_paths_val})

# %%
print(len(df_image_paths_val))# X
print(len(df_label_paths_val))# y
# Out:
# 267
# 267

# %%
index_tab = []
for el in df_image_paths_val['Image_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_image_paths_val['Index'] = index_tab

# %%
index_tab = []
for el in df_label_paths_val['Target_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_label_paths_val['Index'] = index_tab

# %%
df_val = pd.merge(df_image_paths_val, df_label_paths_val, on='Index', how='left')
df_test = df_val.loc[36:50]
df_val = df_val.loc[:35]
df_val
# Out:
#                       Index                                Image_Path  \
# 0   frankfurt_000001_044525  ./images_val/frankfurt_000001_044525.png
# 1   frankfurt_000001_062509  ./images_val/frankfurt_000001_062509.png
# 2   frankfurt_000001_013496  ./images_val/frankfurt_000001_013496.png
# 3   frankfurt_000001_072295  ./images_val/frankfurt_000001_072295.png
# 4   frankfurt_000001_007622  ./images_val/frankfurt_000001_007622.png
# 5   frankfurt_000000_012121  ./images_val/frankfurt_000000_012121.png
# 6   frankfurt_000001_057954  ./images_val/frankfurt_000001_057954.png
# 7   frankfurt_000000_000294  ./images_val/frankfurt_000000_000294.png
# 8   frankfurt_000001_059789  ./images_val/frankfurt_000001_059789.png
# 9   frankfurt_000000_021879  ./images_val/frankfurt_000000_021879.png
# 10  frankfurt_000000_009688  ./images_val/frankfurt_000000_009688.png
# 11  frankfurt_000001_065850  ./images_val/frankfurt_000001_065850.png
# 12  frankfurt_000001_060135  ./images_val/frankfurt_000001_060135.png
# 13  frankfurt_000001_055603  ./images_val/frankfurt_000001_055603.png
# 14  frankfurt_000001_012038  ./images_val/frankfurt_000001_012038.png
# 15  frankfurt_000001_029086  ./images_val/frankfurt_000001_029086.png
# 16  frankfurt_000001_049770  ./images_val/frankfurt_000001_049770.png
# 17  frankfurt_000001_062250  ./images_val/frankfurt_000001_062250.png
# 18  frankfurt_000001_002759  ./images_val/frankfurt_000001_002759.png
# 19  frankfurt_000000_001016  ./images_val/frankfurt_000000_001016.png
# 20  frankfurt_000001_078803  ./images_val/frankfurt_000001_078803.png
# 21  frankfurt_000001_018113  ./images_val/frankfurt_000001_018113.png
# 22  frankfurt_000001_032711  ./images_val/frankfurt_000001_032711.png
# 23  frankfurt_000000_011007  ./images_val/frankfurt_000000_011007.png
# 24  frankfurt_000000_017476  ./images_val/frankfurt_000000_017476.png
# 25  frankfurt_000001_030310  ./images_val/frankfurt_000001_030310.png
# 26  frankfurt_000001_052594  ./images_val/frankfurt_000001_052594.png
# 27  frankfurt_000001_003056  ./images_val/frankfurt_000001_003056.png
# 28  frankfurt_000001_041517  ./images_val/frankfurt_000001_041517.png
# 29  frankfurt_000001_054640  ./images_val/frankfurt_000001_054640.png
# 30  frankfurt_000001_007973  ./images_val/frankfurt_000001_007973.png
# 31  frankfurt_000001_023769  ./images_val/frankfurt_000001_023769.png
# 32  frankfurt_000001_030067  ./images_val/frankfurt_000001_030067.png
# 33  frankfurt_000001_055172  ./images_val/frankfurt_000001_055172.png
# 34  frankfurt_000001_046126  ./images_val/frankfurt_000001_046126.png
# 35  frankfurt_000000_013942  ./images_val/frankfurt_000000_013942.png
#
#                                 Target_Path
# 0   ./masks_val/frankfurt_000001_044525.png
# 1   ./masks_val/frankfurt_000001_062509.png
# 2   ./masks_val/frankfurt_000001_013496.png
# 3   ./masks_val/frankfurt_000001_072295.png
# 4   ./masks_val/frankfurt_000001_007622.png
# 5   ./masks_val/frankfurt_000000_012121.png
# 6   ./masks_val/frankfurt_000001_057954.png
# 7   ./masks_val/frankfurt_000000_000294.png
# 8   ./masks_val/frankfurt_000001_059789.png
# 9   ./masks_val/frankfurt_000000_021879.png
# 10  ./masks_val/frankfurt_000000_009688.png
# 11  ./masks_val/frankfurt_000001_065850.png
# 12  ./masks_val/frankfurt_000001_060135.png
# 13  ./masks_val/frankfurt_000001_055603.png
# 14  ./masks_val/frankfurt_000001_012038.png
# 15  ./masks_val/frankfurt_000001_029086.png
# 16  ./masks_val/frankfurt_000001_049770.png
# 17  ./masks_val/frankfurt_000001_062250.png
# 18  ./masks_val/frankfurt_000001_002759.png
# 19  ./masks_val/frankfurt_000000_001016.png
# 20  ./masks_val/frankfurt_000001_078803.png
# 21  ./masks_val/frankfurt_000001_018113.png
# 22  ./masks_val/frankfurt_000001_032711.png
# 23  ./masks_val/frankfurt_000000_011007.png
# 24  ./masks_val/frankfurt_000000_017476.png
# 25  ./masks_val/frankfurt_000001_030310.png
# 26  ./masks_val/frankfurt_000001_052594.png
# 27  ./masks_val/frankfurt_000001_003056.png
# 28  ./masks_val/frankfurt_000001_041517.png
# 29  ./masks_val/frankfurt_000001_054640.png
# 30  ./masks_val/frankfurt_000001_007973.png
# 31  ./masks_val/frankfurt_000001_023769.png
# 32  ./masks_val/frankfurt_000001_030067.png
# 33  ./masks_val/frankfurt_000001_055172.png
# 34  ./masks_val/frankfurt_000001_046126.png
# 35  ./masks_val/frankfurt_000000_013942.png

# %%
df_test = df_test.reset_index()
df_test
# Out:
#     index                    Index                                Image_Path  \
# 0      36  frankfurt_000001_015768  ./images_val/frankfurt_000001_015768.png
# 1      37  frankfurt_000001_010600  ./images_val/frankfurt_000001_010600.png
# 2      38  frankfurt_000001_023235  ./images_val/frankfurt_000001_023235.png
# 3      39  frankfurt_000001_068208  ./images_val/frankfurt_000001_068208.png
# 4      40  frankfurt_000001_051516  ./images_val/frankfurt_000001_051516.png
# 5      41  frankfurt_000001_080830  ./images_val/frankfurt_000001_080830.png
# 6      42  frankfurt_000001_005184  ./images_val/frankfurt_000001_005184.png
# 7      43  frankfurt_000001_027325  ./images_val/frankfurt_000001_027325.png
# 8      44  frankfurt_000001_023369  ./images_val/frankfurt_000001_023369.png
# 9      45  frankfurt_000000_018797  ./images_val/frankfurt_000000_018797.png
# 10     46  frankfurt_000001_016462  ./images_val/frankfurt_000001_016462.png
# 11     47  frankfurt_000001_058057  ./images_val/frankfurt_000001_058057.png
# 12     48  frankfurt_000001_053102  ./images_val/frankfurt_000001_053102.png
# 13     49  frankfurt_000001_060906  ./images_val/frankfurt_000001_060906.png
# 14     50  frankfurt_000001_048654  ./images_val/frankfurt_000001_048654.png
#
#                                 Target_Path
# 0   ./masks_val/frankfurt_000001_015768.png
# 1   ./masks_val/frankfurt_000001_010600.png
# 2   ./masks_val/frankfurt_000001_023235.png
# 3   ./masks_val/frankfurt_000001_068208.png
# 4   ./masks_val/frankfurt_000001_051516.png
# 5   ./masks_val/frankfurt_000001_080830.png
# 6   ./masks_val/frankfurt_000001_005184.png
# 7   ./masks_val/frankfurt_000001_027325.png
# 8   ./masks_val/frankfurt_000001_023369.png
# 9   ./masks_val/frankfurt_000000_018797.png
# 10  ./masks_val/frankfurt_000001_016462.png
# 11  ./masks_val/frankfurt_000001_058057.png
# 12  ./masks_val/frankfurt_000001_053102.png
# 13  ./masks_val/frankfurt_000001_060906.png
# 14  ./masks_val/frankfurt_000001_048654.png

# %% [markdown]
# # Création modèle

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
#from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.losses import BinaryCrossentropy
from keras.losses import SparseCategoricalCrossentropy
#from keras.losses import CategoricalCrossentropy
#import os
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import albumentations as A
#from keras.utils import to_categorical
#import matplotlib.pyplot as plt
# Out:
# 2024-04-16 20:43:58.832103: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def unet_model(input_shape, num_classes):
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(conv5)
    drop5 = Dropout(0.5)(conv5)

    # Decoder
    up6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(drop5)
    up6 = concatenate([up6, drop4], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(up6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(conv6)

    up7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
    up7 = concatenate([up7, conv3], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(up7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(conv7)

    up8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
    up8 = concatenate([up8, conv2], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(up8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(conv8)

    up9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
    up9 = concatenate([up9, conv1], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(up9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(conv9)

    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(conv9)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

input_shape = (256, 256, 3)  # Taille d'entrée de l'image
num_classes = 8
model = unet_model(input_shape, num_classes)

# %%
transform = A.Compose([
    A.HorizontalFlip(p=1.0)
])

# %%
input_shape2 = (256, 256, 3)

def load_data(df):
    images_tab = []
    masks_tab = []
    for i in range(len(df)):
        image_path = df['Image_Path'][i]
        mask_path = df['Target_Path'][i]
        image = img_to_array(Image.open(image_path).convert('RGB').resize(input_shape[:2]))
        image = image.astype(np.uint8)
        images_tab.append(image)

        mask = img_to_array(Image.open(mask_path).resize(input_shape2[:2], Image.NEAREST))
        mask = mask.astype(np.uint8)
        for x in range(mask.shape[0]):
            for y in range(mask.shape[1]):
                if (mask[x, y] == [250, 170, 30]).all():
                    mask[x, y] = 0
                elif (mask[x, y] == [0, 0, 142]).all():
                    mask[x, y] = 1
                elif (mask[x, y] == [102, 102, 156]).all():
                    mask[x, y] = 2
                elif (mask[x, y] == [220, 20, 60]).all():
                    mask[x, y] = 3
                elif (mask[x, y] == [153, 153, 153]).all():
                    mask[x, y] = 4
                elif (mask[x, y] == [244, 35, 232]).all():
                    mask[x, y] = 5
                elif (mask[x, y] == [70, 70, 70]).all():
                    mask[x, y] = 6
                elif (mask[x, y] == [70, 130, 180]).all():
                    mask[x, y] = 7
        mask = mask[:, :, 0:1]
        masks_tab.append(mask)

        transformed = transform(image=image, mask=mask)
        transformed_img = transformed['image']
        images_tab.append(transformed_img)

        transformed_img = transformed['mask']
        for x in range(transformed_img.shape[0]):
            for y in range(transformed_img.shape[1]):
                if (transformed_img[x, y] == [250, 170, 30]).all():
                    transformed_img[x, y] = 0
                elif (transformed_img[x, y] == [0, 0, 142]).all():
                    transformed_img[x, y] = 1
                elif (transformed_img[x, y] == [102, 102, 156]).all():
                    transformed_img[x, y] = 2
                elif (transformed_img[x, y] == [220, 20, 60]).all():
                    transformed_img[x, y] = 3
                elif (transformed_img[x, y] == [153, 153, 153]).all():
                    transformed_img[x, y] = 4
                elif (transformed_img[x, y] == [244, 35, 232]).all():
                    transformed_img[x, y] = 5
                elif (transformed_img[x, y] == [70, 70, 70]).all():
                    transformed_img[x, y] = 6
                elif (transformed_img[x, y] == [70, 130, 180]).all():
                    transformed_img[x, y] = 7
        transformed_img = transformed_img[:, :, 0:1]
        masks_tab.append(transformed_img)

    images_tab = np.array(images_tab)
    masks_tab = np.array(masks_tab)
    return images_tab, masks_tab

# %%
images, masks = load_data(df_train)
images_val, masks_val = load_data(df_val)
print("Nombre total d'images chargées:", len(images))
print("Nombre total de masks chargées:", len(masks))
print("Nombre total d'images de validation chargées:", len(images_val))
print("Nombre total de masks de validation chargées:", len(masks_val))
print("Shape images :", images.shape)
print("Shape masks :", masks.shape)
print("Shape images_val :", images_val.shape)
print("Shape masks_val :", masks_val.shape)
# Out:
# Nombre total d'images chargées: 348
# Nombre total de masks chargées: 348
# Nombre total d'images de validation chargées: 72
# Nombre total de masks de validation chargées: 72
# Shape images : (348, 256, 256, 3)
# Shape masks : (348, 256, 256, 1)
# Shape images_val : (72, 256, 256, 3)
# Shape masks_val : (72, 256, 256, 1)

# %%
X_train = images.copy()
X_val = images_val.copy()
y_train = masks.copy()
y_val = masks_val.copy()

# %% [markdown]
# # Test d'affichage

# %%
first_image_array = X_train[5].copy()
first_image_array = np.uint8(first_image_array)
pil_image = Image.fromarray(first_image_array)
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
first_mask_array = y_train[5].copy()
first_mask_array = np.uint8(first_mask_array)
transformed_array = np.repeat(first_mask_array, 3, axis=2)
print(transformed_array.shape)
# Out:
# (256, 256, 3)

# %%
for x in range(transformed_array.shape[0]):
    for y in range(transformed_array.shape[1]):
        if (transformed_array[x, y] == [0, 0, 0]).all():
            transformed_array[x, y] = [250, 170, 30]
        elif (transformed_array[x, y] == [1, 1, 1]).all():
            transformed_array[x, y] = [0, 0, 142]
        elif (transformed_array[x, y] == [2, 2, 2]).all():
            transformed_array[x, y] = [102, 102, 156]
        elif (transformed_array[x, y] == [3, 3, 3]).all():
            transformed_array[x, y] = [220, 20, 60]
        elif (transformed_array[x, y] == [4, 4, 4]).all():
            transformed_array[x, y] = [153, 153, 153]
        elif (transformed_array[x, y] == [5, 5, 5]).all():
            transformed_array[x, y] = [244, 35, 232]
        elif (transformed_array[x, y] == [6, 6, 6]).all():
            transformed_array[x, y] = [70, 70, 70]
        elif (transformed_array[x, y] == [7, 7, 7]).all():
            transformed_array[x, y] = [70, 130, 180]

# %%
pil_mask = Image.fromarray(transformed_array)
pil_mask
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
from tensorflow.keras import backend as K  # type: ignore
import tensorflow as tf # type: ignore
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # delete alert message from Tensorflow

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    
    inputs = K.flatten(y_pred)
    targets = K.flatten(y_true)

    targets = K.expand_dims(targets, axis=-1)
    inputs = K.expand_dims(inputs, axis=-1)

    intersection = K.sum(targets * inputs)
    return (2*intersection + smooth) / (K.sum(targets) + K.sum(inputs) + smooth)


def dice_coeff_multiclass(y_true, y_pred, smooth=1e-6):
    y_true = y_true.numpy() # shape(32, 256, 256, 1)
    y_pred = y_pred.numpy() # shape(32, 256, 256, 8)

    tensor_mean = []

    for i in range(len(y_true)):
        mask1 = y_pred[i].copy()
        segmentation_map = np.argmax(mask1, axis=-1)
        tableau_transforme = np.expand_dims(segmentation_map, axis=-1)
        first_mask_array = np.uint8(tableau_transforme)

        num_class_pred = len(np.unique(first_mask_array))
        num_class_true = len(np.unique(y_true[i]))

        if num_class_pred != num_class_true:
            num_class = np.unique(y_true[i])
        else :
            num_class = np.unique(y_true[i])
        
        el_unique = []
        for el in num_class:
            el_unique.append(el)

        dice_mean = []

        for value in el_unique:
            binary_pred = np.copy(first_mask_array)
            binary_pred[first_mask_array == value] = 0
            binary_pred[first_mask_array != value] = 1

            binary_true = np.copy(y_true[i])
            binary_true[y_true[i] == value] = 0
            binary_true[y_true[i] != value] = 1

            dice_mean.append(dice_coef(binary_true, binary_pred).numpy())
            tensor = np.mean(dice_mean)

        tensor_mean.append(tensor)

    return np.mean(tensor_mean)

# %%
def iou(y_true, y_pred, smooth=1e-6):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(K.abs(y_true * y_pred))
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return K.mean((intersection + smooth) / (union + smooth))


def iou_multiclass(y_true, y_pred, smooth=1e-6):
    y_true = y_true.numpy() # shape(32, 256, 256, 1)
    y_pred = y_pred.numpy() # shape(32, 256, 256, 8)

    tensor_mean = []

    for i in range(len(y_true)):
        mask1 = y_pred[i].copy()
        segmentation_map = np.argmax(mask1, axis=-1)
        tableau_transforme = np.expand_dims(segmentation_map, axis=-1)
        first_mask_array = np.uint8(tableau_transforme)

        num_class_pred = len(np.unique(first_mask_array))
        num_class_true = len(np.unique(y_true[i]))

        if num_class_pred != num_class_true:
            num_class = np.unique(y_true[i])
        else :
            num_class = np.unique(y_true[i])
        
        el_unique = []
        for el in num_class:
            el_unique.append(el)

        dice_mean = []

        for value in el_unique:
            binary_pred = np.copy(first_mask_array)
            binary_pred[first_mask_array == value] = 0
            binary_pred[first_mask_array != value] = 1

            binary_true = np.copy(y_true[i])
            binary_true[y_true[i] == value] = 0
            binary_true[y_true[i] != value] = 1

            dice_mean.append(iou(binary_true, binary_pred).numpy())
            tensor = np.mean(dice_mean)

        tensor_mean.append(tensor)

    return np.mean(tensor_mean)

# %%
tf.keras.utils.get_custom_objects()['dice_coeff_multiclass'] = dice_coeff_multiclass
tf.keras.utils.get_custom_objects()['iou_multiclass'] = iou_multiclass

model = unet_model(input_shape, num_classes)

model.compile(optimizer=Adam(),
              loss=SparseCategoricalCrossentropy(),
              metrics=['accuracy', dice_coeff_multiclass, iou_multiclass],
              run_eagerly=True)

early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('./models/model_X.keras', monitor='val_loss', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
                    validation_data=(X_val, y_val), 
                    batch_size=32, 
                    epochs=20, 
                    callbacks=[early_stopping, model_checkpoint], 
                    verbose=1)
# Out:
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 119s/step - accuracy: 0.2696 - dice_coeff_multiclass: 0.8350 - iou_multiclass: 0.7802 - loss: 7.7977
# Epoch 1: val_loss improved from inf to 1.73360, saving model to ./models/model_X.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1400s 125s/step - accuracy: 0.2712 - dice_coeff_multiclass: 0.8356 - iou_multiclass: 0.7807 - loss: 7.5780 - val_accuracy: 0.4919 - val_dice_coeff_multiclass: 0.8506 - val_iou_multiclass: 0.8081 - val_loss: 1.7336
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 107s/step - accuracy: 0.4524 - dice_coeff_multiclass: 0.8640 - iou_multiclass: 0.8134 - loss: 1.6668
# Epoch 2: val_loss improved from 1.73360 to 1.51871, saving model to ./models/model_X.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1251s 114s/step - accuracy: 0.4534 - dice_coeff_multiclass: 0.8647 - iou_multiclass: 0.8139 - loss: 1.6628 - val_accuracy: 0.5251 - val_dice_coeff_multiclass: 0.8864 - val_iou_multiclass: 0.8321 - val_loss: 1.5187
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 108s/step - accuracy: 0.4815 - dice_coeff_multiclass: 0.8769 - iou_multiclass: 0.8264 - loss: 8.4257
# Epoch 3: val_loss did not improve from 1.51871
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1255s 114s/step - accuracy: 0.4787 - dice_coeff_multiclass: 0.8751 - iou_multiclass: 0.8251 - loss: 8.4714 - val_accuracy: 0.4881 - val_dice_coeff_multiclass: 0.8402 - val_iou_multiclass: 0.8033 - val_loss: 1.6218
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 106s/step - accuracy: 0.4513 - dice_coeff_multiclass: 0.8456 - iou_multiclass: 0.8045 - loss: 1.6702
# Epoch 4: val_loss did not improve from 1.51871
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1243s 112s/step - accuracy: 0.4517 - dice_coeff_multiclass: 0.8458 - iou_multiclass: 0.8045 - loss: 1.6692 - val_accuracy: 0.4957 - val_dice_coeff_multiclass: 0.8533 - val_iou_multiclass: 0.8099 - val_loss: 1.6244
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 109s/step - accuracy: 0.4606 - dice_coeff_multiclass: 0.8514 - iou_multiclass: 0.8075 - loss: 1.6063
# Epoch 5: val_loss did not improve from 1.51871
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1267s 115s/step - accuracy: 0.4606 - dice_coeff_multiclass: 0.8516 - iou_multiclass: 0.8076 - loss: 1.6048 - val_accuracy: 0.4881 - val_dice_coeff_multiclass: 0.8767 - val_iou_multiclass: 0.8213 - val_loss: 1.5542
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %%
#input_shape = (256, 256, 3)

def predict_image(model, image_path):
    image = Image.open(image_path).convert('RGB').resize(input_shape[:2])
    image_array = img_to_array(image)
    image_array = np.expand_dims(image_array, axis=0)  # Add batch dimension
    mask = model.predict(image_array)
    return mask

image_path = './images_val/frankfurt_000001_031416.png'
#image_path = '../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/test/berlin/berlin_000000_000019_leftImg8bit.png'
predicted_mask = predict_image(model, image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step

# %%
mask1 = predicted_mask[0].copy()
segmentation_map = np.argmax(mask1, axis=-1)
tableau_transforme = np.expand_dims(segmentation_map, axis=-1)
first_mask_array = np.uint8(tableau_transforme)
transformed_array = np.repeat(first_mask_array, 3, axis=2)
for x in range(transformed_array.shape[0]):
    for y in range(transformed_array.shape[1]):
        if (transformed_array[x, y] == [0, 0, 0]).all():
            transformed_array[x, y] = [250, 170, 30]
        elif (transformed_array[x, y] == [1, 1, 1]).all():
            transformed_array[x, y] = [0, 0, 142]
        elif (transformed_array[x, y] == [2, 2, 2]).all():
            transformed_array[x, y] = [102, 102, 156]
        elif (transformed_array[x, y] == [3, 3, 3]).all():
            transformed_array[x, y] = [220, 20, 60]
        elif (transformed_array[x, y] == [4, 4, 4]).all():
            transformed_array[x, y] = [153, 153, 153]
        elif (transformed_array[x, y] == [5, 5, 5]).all():
            transformed_array[x, y] = [244, 35, 232]
        elif (transformed_array[x, y] == [6, 6, 6]).all():
            transformed_array[x, y] = [70, 70, 70]
        elif (transformed_array[x, y] == [7, 7, 7]).all():
            transformed_array[x, y] = [70, 130, 180]

# %%
pil_mask = Image.fromarray(transformed_array)
pil_mask = pil_mask.resize((2048, 1024))

# %%
pil_mask = pil_mask.convert("RGBA")
transparency = 128
mask_data = [(r, g, b, transparency) for r, g, b, _ in pil_mask.getdata()]
pil_mask.putdata(mask_data)

# %%
test1 = Image.open(image_path)
test1.paste(pil_mask, (0, 0), pil_mask)
test1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2048x1024>

# %%
lossX = history.history['loss']    
val_lossX = history.history['val_loss']    
accX = history.history['accuracy']    
val_accX = history.history['val_accuracy']    
dice_coefX = history.history.get('dice_coeff_multiclass', [])  
val_dice_coefX = history.history.get('val_dice_coeff_multiclass', [])  
iouX = history.history.get('iou_multiclass', [])  
val_iouX = history.history.get('val_iou_multiclass', [])

# %%
_epochs = list(range(1, len(lossX) + 1))

# %%
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot    
plt.plot(_epochs, lossX, 'y', label='Loss Train')    
plt.plot(_epochs, val_lossX, 'r', label='Loss Val')    
plt.title('Loss Train & Val')    
plt.xlabel('Epochs')    
plt.ylabel('Loss')    
plt.legend()

# %%
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot    
plt.plot(_epochs, accX, 'y', label='Accuracy Train')    
plt.plot(_epochs, val_accX, 'r', label='Accuracy Val')    
plt.title('Accuracy Train & Val')    
plt.xlabel('Epochs')    
plt.ylabel('Accuracy')    
plt.legend()

# %%
plt.subplot(2, 2, 3) # 2 rows, 2 columns, 3rd subplot  
plt.plot(_epochs, dice_coefX, 'g', label='Dice Coef Train')  
plt.plot(_epochs, val_dice_coefX, 'b', label='Dice Coef Val')  
plt.title('Dice Coefficient Train & Val')  
plt.xlabel('Epochs')  
plt.ylabel('Dice Coefficient')  
plt.legend()

# %%
plt.subplot(2, 2, 4)  # 2 rows, 2 columns, 4th subplot  
plt.plot(_epochs, iouX, 'g', label='IoU Train')  
plt.plot(_epochs, val_iouX, 'b', label='IoU Val')  
plt.title('IoU Train & Val')  
plt.xlabel('Epochs')  
plt.ylabel('IoU')  
plt.legend()

# %%
plt.plot(_epochs, iouX, 'g', label='IoU Train')  
plt.plot(_epochs, val_iouX, 'b', label='IoU Val')  
plt.title('IoU Train & Val')  
plt.xlabel('Epochs')  
plt.ylabel('IoU')  
plt.legend()

# %%
lossX = history.history['loss']    
val_lossX = history.history['val_loss']    
accX = history.history['accuracy']    
val_accX = history.history['val_accuracy']    
dice_coefX = history.history.get('dice_coef', [])  
val_dice_coefX = history.history.get('val_dice_coef', [])  
iouX = history.history.get('iou', [])  
val_iouX = history.history.get('val_iou', [])

def save_metrics(metric_name, metric_train, metric_val):
    plt.plot(_epochs, metric_train, 'g', label=f'{metric_name} Train')  
    plt.plot(_epochs, metric_val, 'b', label=f'{metric_name} Val')  
    plt.title(f'{metric_name} Train & Val')  
    plt.xlabel('Epochs')  
    plt.ylabel(f'{metric_name}')  
    plt.legend()
    plt.savefig(f'{metric_name}.png')
    plt.close()

# %%
save_metrics('Accuracy', lossX, val_lossX)
