# %%
import numpy as np
import json
from PIL import Image, ImageDraw
import os
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
train_image_dir = "./images"

image_paths_train = []

for i in os.listdir(train_image_dir):
    folder_path = os.path.join(train_image_dir, i)
    if i != '.DS_Store':
        image_paths_train.append(folder_path)

# %%
train_label_dir = "../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen"

label_paths_train = []

for i in os.listdir(train_label_dir):
    folder_path = os.path.join(train_label_dir, i)
    if i != '.DS_Store':
        label_paths_train.append(folder_path)

# %%
df_image_paths_train = pd.DataFrame({"Index": "", "Image_Path": image_paths_train})
df_label_paths_train = pd.DataFrame({"Index": "", "Target_Path": label_paths_train})

# %%
filter_instanceIds = df_label_paths_train[df_label_paths_train['Target_Path'].str.contains('instanceIds')]
filter_polygons = df_label_paths_train[df_label_paths_train['Target_Path'].str.contains('polygons')]
filter_labelIds = df_label_paths_train[df_label_paths_train['Target_Path'].str.contains('labelIds')]

df_label_paths_train = df_label_paths_train.drop(filter_instanceIds.index)
df_label_paths_train = df_label_paths_train.drop(filter_polygons.index)
df_label_paths_train = df_label_paths_train.drop(filter_labelIds.index)

# %%
print(len(df_image_paths_train))# X
print(len(df_label_paths_train))# y
# Out:
# 174
# 174

# %%
index_tab = []
for el in df_image_paths_train['Image_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_image_paths_train['Index'] = index_tab

# %%
index_tab = []
for el in df_label_paths_train['Target_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    file_name = file_name.replace("_gtFine_color", "")
    index_tab.append(file_name)
df_label_paths_train['Index'] = index_tab

# %%
df_train = pd.merge(df_image_paths_train, df_label_paths_train, on='Index', how='left')
df_train
# Out:
#                     Index                         Image_Path  \
# 0    aachen_000008_000019  ./images/aachen_000008_000019.png
# 1    aachen_000149_000019  ./images/aachen_000149_000019.png
# 2    aachen_000095_000019  ./images/aachen_000095_000019.png
# 3    aachen_000014_000019  ./images/aachen_000014_000019.png
# 4    aachen_000023_000019  ./images/aachen_000023_000019.png
# ..                    ...                                ...
# 169  aachen_000053_000019  ./images/aachen_000053_000019.png
# 170  aachen_000112_000019  ./images/aachen_000112_000019.png
# 171  aachen_000125_000019  ./images/aachen_000125_000019.png
# 172  aachen_000006_000019  ./images/aachen_000006_000019.png
# 173  aachen_000031_000019  ./images/aachen_000031_000019.png
#
#                                                                                                    Target_Path
# 0    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000008_000019_gtFine_color.png
# 1    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000149_000019_gtFine_color.png
# 2    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000095_000019_gtFine_color.png
# 3    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000014_000019_gtFine_color.png
# 4    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000023_000019_gtFine_color.png
# ..                                                                                                         ...
# 169  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000053_000019_gtFine_color.png
# 170  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000112_000019_gtFine_color.png
# 171  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000125_000019_gtFine_color.png
# 172  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000006_000019_gtFine_color.png
# 173  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000031_000019_gtFine_color.png
#
# [174 rows x 3 columns]

# %%
val_image_dir = "./images_val"

image_paths_val = []

for i in os.listdir(val_image_dir):
    folder_path = os.path.join(val_image_dir, i)
    if i != '.DS_Store':
        image_paths_val.append(folder_path)

# %%
val_label_dir = "../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt"

label_paths_val = []

for i in os.listdir(val_label_dir):
    folder_path = os.path.join(val_label_dir, i)
    if i != '.DS_Store':
        label_paths_val.append(folder_path)

# %%
df_image_paths_val = pd.DataFrame({"Index": "", "Image_Path": image_paths_val})
df_label_paths_val = pd.DataFrame({"Index": "", "Target_Path": label_paths_val})

# %%
filter_instanceIds = df_label_paths_val[df_label_paths_val['Target_Path'].str.contains('instanceIds')]
filter_polygons = df_label_paths_val[df_label_paths_val['Target_Path'].str.contains('polygons')]
filter_labelIds = df_label_paths_val[df_label_paths_val['Target_Path'].str.contains('labelIds')]

df_label_paths_val = df_label_paths_val.drop(filter_instanceIds.index)
df_label_paths_val = df_label_paths_val.drop(filter_polygons.index)
df_label_paths_val = df_label_paths_val.drop(filter_labelIds.index)

# %%
print(len(df_image_paths_val))# X
print(len(df_label_paths_val))# y
# Out:
# 36
# 267

# %%
index_tab = []
for el in df_image_paths_val['Image_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_image_paths_val['Index'] = index_tab

# %%
index_tab = []
for el in df_label_paths_val['Target_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    file_name = file_name.replace("_gtFine_color", "")
    index_tab.append(file_name)
df_label_paths_val['Index'] = index_tab

# %%
df_val = pd.merge(df_image_paths_val, df_label_paths_val, on='Index', how='left')
df_val
# Out:
#                       Index                                Image_Path  \
# 0   frankfurt_000001_013496  ./images_val/frankfurt_000001_013496.png
# 1   frankfurt_000001_072295  ./images_val/frankfurt_000001_072295.png
# 2   frankfurt_000001_065850  ./images_val/frankfurt_000001_065850.png
# 3   frankfurt_000001_062250  ./images_val/frankfurt_000001_062250.png
# 4   frankfurt_000001_054640  ./images_val/frankfurt_000001_054640.png
# 5   frankfurt_000001_051516  ./images_val/frankfurt_000001_051516.png
# 6   frankfurt_000000_018797  ./images_val/frankfurt_000000_018797.png
# 7   frankfurt_000001_042384  ./images_val/frankfurt_000001_042384.png
# 8   frankfurt_000001_008688  ./images_val/frankfurt_000001_008688.png
# 9   frankfurt_000001_054219  ./images_val/frankfurt_000001_054219.png
# 10  frankfurt_000001_032942  ./images_val/frankfurt_000001_032942.png
# 11  frankfurt_000001_050686  ./images_val/frankfurt_000001_050686.png
# 12  frankfurt_000000_016286  ./images_val/frankfurt_000000_016286.png
# 13  frankfurt_000000_015389  ./images_val/frankfurt_000000_015389.png
# 14  frankfurt_000001_042733  ./images_val/frankfurt_000001_042733.png
# 15  frankfurt_000000_009969  ./images_val/frankfurt_000000_009969.png
# 16  frankfurt_000001_035144  ./images_val/frankfurt_000001_035144.png
# 17  frankfurt_000000_013067  ./images_val/frankfurt_000000_013067.png
# 18  frankfurt_000001_033655  ./images_val/frankfurt_000001_033655.png
# 19  frankfurt_000000_007365  ./images_val/frankfurt_000000_007365.png
# 20  frankfurt_000001_075984  ./images_val/frankfurt_000001_075984.png
# 21  frankfurt_000001_073243  ./images_val/frankfurt_000001_073243.png
# 22  frankfurt_000001_063045  ./images_val/frankfurt_000001_063045.png
# 23  frankfurt_000001_077434  ./images_val/frankfurt_000001_077434.png
# 24  frankfurt_000001_017101  ./images_val/frankfurt_000001_017101.png
# 25  frankfurt_000001_073911  ./images_val/frankfurt_000001_073911.png
# 26  frankfurt_000000_000576  ./images_val/frankfurt_000000_000576.png
# 27  frankfurt_000001_003588  ./images_val/frankfurt_000001_003588.png
# 28  frankfurt_000001_038245  ./images_val/frankfurt_000001_038245.png
# 29  frankfurt_000000_004617  ./images_val/frankfurt_000000_004617.png
# 30  frankfurt_000000_001751  ./images_val/frankfurt_000000_001751.png
# 31  frankfurt_000001_031416  ./images_val/frankfurt_000001_031416.png
# 32  frankfurt_000001_080391  ./images_val/frankfurt_000001_080391.png
# 33  frankfurt_000001_025512  ./images_val/frankfurt_000001_025512.png
# 34  frankfurt_000001_067735  ./images_val/frankfurt_000001_067735.png
# 35  frankfurt_000001_046504  ./images_val/frankfurt_000001_046504.png
#
#                                                                                                       Target_Path
# 0   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_013496_gtFine_color.png
# 1   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_072295_gtFine_color.png
# 2   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_065850_gtFine_color.png
# 3   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_062250_gtFine_color.png
# 4   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_054640_gtFine_color.png
# 5   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_051516_gtFine_color.png
# 6   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_018797_gtFine_color.png
# 7   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_042384_gtFine_color.png
# 8   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_008688_gtFine_color.png
# 9   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_054219_gtFine_color.png
# 10  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_032942_gtFine_color.png
# 11  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_050686_gtFine_color.png
# 12  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_016286_gtFine_color.png
# 13  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_015389_gtFine_color.png
# 14  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_042733_gtFine_color.png
# 15  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_009969_gtFine_color.png
# 16  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_035144_gtFine_color.png
# 17  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_013067_gtFine_color.png
# 18  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_033655_gtFine_color.png
# 19  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_007365_gtFine_color.png
# 20  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_075984_gtFine_color.png
# 21  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_073243_gtFine_color.png
# 22  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_063045_gtFine_color.png
# 23  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_077434_gtFine_color.png
# 24  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_017101_gtFine_color.png
# 25  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_073911_gtFine_color.png
# 26  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_000576_gtFine_color.png
# 27  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_003588_gtFine_color.png
# 28  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_038245_gtFine_color.png
# 29  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_004617_gtFine_color.png
# 30  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_001751_gtFine_color.png
# 31  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_031416_gtFine_color.png
# 32  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_080391_gtFine_color.png
# 33  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_025512_gtFine_color.png
# 34  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_067735_gtFine_color.png
# 35  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_046504_gtFine_color.png

# %%
from keras.losses import CategoricalCrossentropy
from keras.layers import Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate, Input
from keras.models import Model
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy
import numpy as np
from PIL import Image
from keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt

# %%
def unet_model(input_shape, num_classes):
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(conv5)
    drop5 = Dropout(0.5)(conv5)

    # Decoder
    up6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(drop5)
    up6 = concatenate([up6, drop4], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(up6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(conv6)

    up7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
    up7 = concatenate([up7, conv3], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(up7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(conv7)

    up8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
    up8 = concatenate([up8, conv2], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(up8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(conv8)

    up9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
    up9 = concatenate([up9, conv1], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(up9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(conv9)

    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(conv9)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

input_shape = (256, 256, 3)  # Taille d'entrée de l'image
num_classes = 3
model = unet_model(input_shape, num_classes)

# %%
def load_data(df):
    images_tab = []
    masks_tab = []
    for i in range(len(df)):
        image_path = df['Image_Path'][i]
        mask_path = df['Target_Path'][i]
        image = img_to_array(Image.open(image_path).convert('RGB').resize(input_shape[:2]))
        mask = img_to_array(Image.open(mask_path).convert('RGB').resize(input_shape[:2]))
        mask = np.expand_dims(mask, axis=-1)
        images_tab.append(image)
        masks_tab.append(mask)
    images_tab = np.array(images_tab)
    masks_tab = np.array(masks_tab)
    return images_tab, masks_tab

# %%
images, masks = load_data(df_train)
images_val, masks_val = load_data(df_val)
print("Nombre total d'images chargées:", len(images))
print("Nombre total de masks chargées:", len(masks))
print("Nombre total d'images val chargées:", len(images_val))
print("Nombre total de masks val chargées:", len(masks_val))
# Out:
# Nombre total d'images chargées: 174
# Nombre total de masks chargées: 174
# Nombre total d'images val chargées: 36
# Nombre total de masks val chargées: 36

# %%
print(masks.shape)
print(images.shape)
# Out:
# (174, 256, 256, 3, 1)
# (174, 256, 256, 3)

# %%
#masks = np.squeeze(masks)

# Vérifier à nouveau la forme des masques
print(masks.shape)
# Out:
# (174, 256, 256, 4)

# %%
# Normalisation des données
X_train = images / 255.0
X_val = images_val / 255.0
y_train = masks / 255.0
y_val = masks_val / 255.0

# %%
input_shape = (256, 256, 3)
model = unet_model(input_shape, num_classes)

model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=2, verbose=1)
# Out:
# Epoch 1/2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 5
#       2 model = unet_model(input_shape, num_classes)
#       4 model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])
# ----> 5 history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=2, verbose=1)
#
# File /Applications/anaconda3/envs/VisionTransport/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:123, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#     121     # To get the full stack trace, call:
#     122     # `keras.config.disable_traceback_filtering()`
# --> 123     raise e.with_traceback(filtered_tb) from None
#     124 finally:
#     125     del filtered_tb
#
# File /Applications/anaconda3/envs/VisionTransport/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py:616, in sparse_categorical_crossentropy(target, output, from_logits, axis)
#     610     raise ValueError(
#     611         "Argument `output` must be at least rank 1. "
#     612         "Received: "
#     613         f"output.shape={output.shape}"
#     614     )
#     615 if len(target.shape) != len(output.shape[:-1]):
# --> 616     raise ValueError(
#     617         "Argument `output` must have rank (ndim) `target.ndim - 1`. "
#     618         "Received: "
#     619         f"target.shape={target.shape}, output.shape={output.shape}"
#     620     )
#     621 for e1, e2 in zip(target.shape, output.shape[:-1]):
#     622     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Argument `output` must have rank (ndim) `target.ndim - 1`. Received: target.shape=(None, 256, 256, 3), output.shape=(None, 256, 256, 3)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.preprocessing.image import img_to_array, ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from keras.utils import to_categorical
import numpy as np
from PIL import Image

def unet_model(input_shape, num_classes):
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(conv5)
    drop5 = Dropout(0.5)(conv5)

    # Decoder
    up6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(drop5)
    up6 = concatenate([up6, drop4], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(up6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(conv6)

    up7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
    up7 = concatenate([up7, conv3], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(up7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(conv7)

    up8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
    up8 = concatenate([up8, conv2], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(up8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(conv8)

    up9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
    up9 = concatenate([up9, conv1], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(up9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(conv9)

    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(conv9)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

input_shape = (256, 256, 3)  # Taille d'entrée de l'image
num_classes = 8

model = unet_model(input_shape, num_classes)

def load_data(df, input_shape, num_classes):
    images_tab = []
    masks_tab = []
    for i in range(len(df)):
        image_path = df['Image_Path'][i]
        mask_path = df['Target_Path'][i]
        image = img_to_array(Image.open(image_path).convert('RGB').resize(input_shape[:2]))
        mask = img_to_array(Image.open(mask_path).convert('RGB').resize((input_shape[:2])))
        images_tab.append(image)
        masks_tab.append(mask)
    images_tab = np.array(images_tab)
    masks_tab = np.array(masks_tab)
    return images_tab, masks_tab

images, masks = load_data(df_train, input_shape, num_classes)
images_val, masks_val = load_data(df_val, input_shape, num_classes)

X_train = images / 255.0
X_val = images_val / 255.0
y_train = masks
y_val = masks_val
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)

model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=2, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 88
#      86 y_train = masks
#      87 y_val = masks_val
# ---> 88 y_train = to_categorical(y_train, num_classes)
#      89 y_val = to_categorical(y_val, num_classes)
#      91 model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])
#
# File /Applications/anaconda3/envs/VisionTransport/lib/python3.10/site-packages/keras/src/utils/numerical_utils.py:89, in to_categorical(x, num_classes)
#      87 batch_size = x.shape[0]
#      88 categorical = np.zeros((batch_size, num_classes))
# ---> 89 categorical[np.arange(batch_size), x] = 1
#      90 output_shape = input_shape + (num_classes,)
#      91 categorical = np.reshape(categorical, output_shape)
#
# IndexError: index 22 is out of bounds for axis 1 with size 8

# %%
max_value = np.max(masks)
min_value = np.min(masks)
print(max_value)
print(min_value)
# Out:
# 255.0
# 0.0
