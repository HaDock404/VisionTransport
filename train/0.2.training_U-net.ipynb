# %%
import pandas as pd

# %%
df_train = pd.read_csv('./Data/df_train.csv')
df_train
# Out:
#                      Index                                         Image_Path  \
# 0     zurich_000069_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 1     zurich_000063_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 2     zurich_000110_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 3     zurich_000016_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 4     zurich_000027_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# ...                    ...                                                ...
# 2970  bremen_000093_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 2971  bremen_000275_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 2972  bremen_000306_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 2973  bremen_000058_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 2974  bremen_000099_000019  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
#
# ...

# %%
df_val = pd.read_csv('./Data/df_val.csv')
df_val
# Out:
#                        Index  \
# 0      munster_000025_000019
# 1      munster_000156_000019
# 2      munster_000050_000019
# 3      munster_000123_000019
# 4      munster_000091_000019
# ..                       ...
# 495  frankfurt_000001_037705
# 496  frankfurt_000000_014480
# 497  frankfurt_000001_051807
# 498  frankfurt_000001_066574
# 499  frankfurt_000000_000294
#
#                                             Image_Path  \
# 0    ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 1    ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 2    ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 3    ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 4    ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# ..                                                 ...
# 495  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 496  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# 497  ./Data/files/Cityscapes_leftImg8bit_trainvalte...
# ...
