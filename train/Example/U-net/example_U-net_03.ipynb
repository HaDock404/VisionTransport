# %%
import numpy as np
import json
from PIL import Image, ImageDraw
import os
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
train_image_dir = "../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen"

image_paths_train = []

for i in os.listdir(train_image_dir):
    folder_path = os.path.join(train_image_dir, i)
    if i != '.DS_Store':
        image_paths_train.append(folder_path)

# %%
train_label_dir = "../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen"

label_paths_train = []

for i in os.listdir(train_label_dir):
    folder_path = os.path.join(train_label_dir, i)
    if i != '.DS_Store':
        label_paths_train.append(folder_path)

# %%
df_image_paths_train = pd.DataFrame({"Index": "", "Image_Path": image_paths_train})
df_label_paths_train = pd.DataFrame({"Index": "", "Target_Path": label_paths_train})

# %%
filter_instanceIds = df_label_paths_train[df_label_paths_train['Target_Path'].str.contains('instanceIds')]
filter_color = df_label_paths_train[df_label_paths_train['Target_Path'].str.contains('color')]
filter_labelIds = df_label_paths_train[df_label_paths_train['Target_Path'].str.contains('labelIds')]

df_label_paths_train = df_label_paths_train.drop(filter_instanceIds.index)
df_label_paths_train = df_label_paths_train.drop(filter_color.index)
df_label_paths_train = df_label_paths_train.drop(filter_labelIds.index)

# %%
print(len(df_image_paths_train))# X
print(len(df_label_paths_train))# y
# Out:
# 174
# 174

# %%
index_tab = []
for el in df_image_paths_train['Image_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    file_name = file_name.replace("_leftImg8bit", "")
    index_tab.append(file_name)
df_image_paths_train['Index'] = index_tab

# %%
index_tab = []
for el in df_label_paths_train['Target_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    file_name = file_name.replace("_gtFine_polygons", "")
    index_tab.append(file_name)
df_label_paths_train['Index'] = index_tab

# %%
df_train = pd.merge(df_image_paths_train, df_label_paths_train, on='Index', how='left')
df_train
# Out:
#                     Index  \
# 0    aachen_000079_000019
# 1    aachen_000073_000019
# 2    aachen_000100_000019
# 3    aachen_000006_000019
# 4    aachen_000037_000019
# ..                    ...
# 169  aachen_000025_000019
# 170  aachen_000156_000019
# 171  aachen_000091_000019
# 172  aachen_000050_000019
# 173  aachen_000123_000019
#
#                                                                                                              Image_Path  \
# 0    ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000079_000019_leftImg8bit.png
# 1    ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000073_000019_leftImg8bit.png
# 2    ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000100_000019_leftImg8bit.png
# 3    ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000006_000019_leftImg8bit.png
# 4    ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000037_000019_leftImg8bit.png
# ..                                                                                                                  ...
# 169  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000025_000019_leftImg8bit.png
# 170  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000156_000019_leftImg8bit.png
# 171  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000091_000019_leftImg8bit.png
# 172  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000050_000019_leftImg8bit.png
# 173  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train/aachen/aachen_000123_000019_leftImg8bit.png
#
#                                                                                                        Target_Path
# 0    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000079_000019_gtFine_polygons.json
# 1    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000073_000019_gtFine_polygons.json
# 2    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000100_000019_gtFine_polygons.json
# 3    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000006_000019_gtFine_polygons.json
# 4    ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000037_000019_gtFine_polygons.json
# ..                                                                                                             ...
# 169  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000025_000019_gtFine_polygons.json
# 170  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000156_000019_gtFine_polygons.json
# 171  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000091_000019_gtFine_polygons.json
# 172  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000050_000019_gtFine_polygons.json
# 173  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/train/aachen/aachen_000123_000019_gtFine_polygons.json
#
# [174 rows x 3 columns]

# %%
val_image_dir = "../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt"

image_paths_val = []

for i in os.listdir(val_image_dir):
    folder_path = os.path.join(val_image_dir, i)
    if i != '.DS_Store':
        image_paths_val.append(folder_path)

# %%
val_label_dir = "../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt"

label_paths_val = []

for i in os.listdir(val_label_dir):
    folder_path = os.path.join(val_label_dir, i)
    if i != '.DS_Store':
        label_paths_val.append(folder_path)

# %%
df_image_paths_val = pd.DataFrame({"Index": "", "Image_Path": image_paths_val})
df_label_paths_val = pd.DataFrame({"Index": "", "Target_Path": label_paths_val})

# %%
filter_instanceIds = df_label_paths_val[df_label_paths_val['Target_Path'].str.contains('instanceIds')]
filter_color = df_label_paths_val[df_label_paths_val['Target_Path'].str.contains('color')]
filter_labelIds = df_label_paths_val[df_label_paths_val['Target_Path'].str.contains('labelIds')]

df_label_paths_val = df_label_paths_val.drop(filter_instanceIds.index)
df_label_paths_val = df_label_paths_val.drop(filter_color.index)
df_label_paths_val = df_label_paths_val.drop(filter_labelIds.index)

# %%
print(len(df_image_paths_val))# X
print(len(df_label_paths_val))# y
# Out:
# 267
# 267

# %%
index_tab = []
for el in df_image_paths_val['Image_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    file_name = file_name.replace("_leftImg8bit", "")
    index_tab.append(file_name)
df_image_paths_val['Index'] = index_tab

# %%
index_tab = []
for el in df_label_paths_val['Target_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    file_name = file_name.replace("_gtFine_polygons", "")
    index_tab.append(file_name)
df_label_paths_val['Index'] = index_tab

# %%
df_val = pd.merge(df_image_paths_val, df_label_paths_val, on='Index', how='left')
df_val = df_val.loc[:35]
df_val
# Out:
#                       Index  \
# 0   frankfurt_000001_046504
# 1   frankfurt_000000_004617
# 2   frankfurt_000001_035144
# 3   frankfurt_000000_000576
# 4   frankfurt_000001_062250
# 5   frankfurt_000001_038245
# 6   frankfurt_000001_073243
# 7   frankfurt_000001_072295
# 8   frankfurt_000001_008688
# 9   frankfurt_000000_016286
# 10  frankfurt_000000_018797
# 11  frankfurt_000000_015389
# 12  frankfurt_000001_075984
# 13  frankfurt_000001_077434
# 14  frankfurt_000000_007365
# 15  frankfurt_000001_013496
# 16  frankfurt_000001_067735
# 17  frankfurt_000001_031416
# 18  frankfurt_000001_042733
# 19  frankfurt_000001_017101
# 20  frankfurt_000001_065850
# 21  frankfurt_000001_073911
# 22  frankfurt_000000_013067
# 23  frankfurt_000000_001751
# 24  frankfurt_000001_033655
# 25  frankfurt_000001_080391
# 26  frankfurt_000001_054640
# 27  frankfurt_000001_051516
# 28  frankfurt_000001_032942
# 29  frankfurt_000001_050686
# 30  frankfurt_000000_009969
# 31  frankfurt_000001_042384
# 32  frankfurt_000001_003588
# 33  frankfurt_000001_025512
# 34  frankfurt_000001_063045
# 35  frankfurt_000001_054219
#
#                                                                                                                 Image_Path  \
# 0   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_046504_leftImg8bit.png
# 1   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_004617_leftImg8bit.png
# 2   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_035144_leftImg8bit.png
# 3   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_000576_leftImg8bit.png
# 4   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_062250_leftImg8bit.png
# 5   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_038245_leftImg8bit.png
# 6   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_073243_leftImg8bit.png
# 7   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_072295_leftImg8bit.png
# 8   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_008688_leftImg8bit.png
# 9   ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_016286_leftImg8bit.png
# 10  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_018797_leftImg8bit.png
# 11  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_015389_leftImg8bit.png
# 12  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_075984_leftImg8bit.png
# 13  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_077434_leftImg8bit.png
# 14  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_007365_leftImg8bit.png
# 15  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_013496_leftImg8bit.png
# 16  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_067735_leftImg8bit.png
# 17  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_031416_leftImg8bit.png
# 18  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_042733_leftImg8bit.png
# 19  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_017101_leftImg8bit.png
# 20  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_065850_leftImg8bit.png
# 21  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_073911_leftImg8bit.png
# 22  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_013067_leftImg8bit.png
# 23  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_001751_leftImg8bit.png
# 24  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_033655_leftImg8bit.png
# 25  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_080391_leftImg8bit.png
# 26  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_054640_leftImg8bit.png
# 27  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_051516_leftImg8bit.png
# 28  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_032942_leftImg8bit.png
# 29  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_050686_leftImg8bit.png
# 30  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000000_009969_leftImg8bit.png
# 31  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_042384_leftImg8bit.png
# 32  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_003588_leftImg8bit.png
# 33  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_025512_leftImg8bit.png
# 34  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_063045_leftImg8bit.png
# 35  ../../Data/files/Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val/frankfurt/frankfurt_000001_054219_leftImg8bit.png
#
#                                                                                                           Target_Path
# 0   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_046504_gtFine_polygons.json
# 1   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_004617_gtFine_polygons.json
# 2   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_035144_gtFine_polygons.json
# 3   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_000576_gtFine_polygons.json
# 4   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_062250_gtFine_polygons.json
# 5   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_038245_gtFine_polygons.json
# 6   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_073243_gtFine_polygons.json
# 7   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_072295_gtFine_polygons.json
# 8   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_008688_gtFine_polygons.json
# 9   ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_016286_gtFine_polygons.json
# 10  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_018797_gtFine_polygons.json
# 11  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_015389_gtFine_polygons.json
# 12  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_075984_gtFine_polygons.json
# 13  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_077434_gtFine_polygons.json
# 14  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_007365_gtFine_polygons.json
# 15  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_013496_gtFine_polygons.json
# 16  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_067735_gtFine_polygons.json
# 17  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_031416_gtFine_polygons.json
# 18  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_042733_gtFine_polygons.json
# 19  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_017101_gtFine_polygons.json
# 20  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_065850_gtFine_polygons.json
# 21  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_073911_gtFine_polygons.json
# 22  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_013067_gtFine_polygons.json
# 23  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_001751_gtFine_polygons.json
# 24  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_033655_gtFine_polygons.json
# 25  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_080391_gtFine_polygons.json
# 26  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_054640_gtFine_polygons.json
# 27  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_051516_gtFine_polygons.json
# 28  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_032942_gtFine_polygons.json
# 29  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_050686_gtFine_polygons.json
# 30  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000000_009969_gtFine_polygons.json
# 31  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_042384_gtFine_polygons.json
# 32  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_003588_gtFine_polygons.json
# 33  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_025512_gtFine_polygons.json
# 34  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_063045_gtFine_polygons.json
# 35  ../../Data/files/Cityscapes_gtFine_trainvaltest/gtFine/val/frankfurt/frankfurt_000001_054219_gtFine_polygons.json

# %% [markdown]
# # Préparation Data Train

# %%
for i in range(len(df_train)):
    img = Image.open(df_train['Image_Path'][i])
    file_path = df_train['Index'][i]
    img.save(f'./images/{file_path}.png')

# %%
for i in range(len(df_train)):
    path_JSON = df_train['Target_Path'][i]
    file_path = df_train['Index'][i]
    with open(path_JSON, 'r') as f:
        json_file = json.load(f)
    img = Image.new("RGB", (json_file['imgWidth'], json_file['imgHeight']), "black")
    draw = ImageDraw.Draw(img)

    for object in json_file['objects']:
        polygon_annotation = []
        """ VEHICLE """
        if object['label'] == 'car':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'truck':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'bus':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'on rails':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'motorcycle':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'bicycle':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'caravan':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'trailer':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
            """ FLAT """
        elif object['label'] == 'road':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(0, 0, 142, 255))
        elif object['label'] == 'sidewalk':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(0, 0, 142, 255))
        elif object['label'] == 'parking':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(0, 0, 142, 255))
        elif object['label'] == 'rail track':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(0, 0, 142, 255))
            """ HUMAN """
        elif object['label'] == 'person':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(102, 102, 156, 255))
        elif object['label'] == 'rider':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(102, 102, 156, 255))
            """ CONSTRUCTION """
        elif object['label'] == 'building':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'wall':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'fence':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'guard rail':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'bridge':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'tunnel':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
            """ OBJECT """
        elif object['label'] == 'pole':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(153, 153, 153, 255))
        elif object['label'] == 'pole group':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(153, 153, 153, 255))
        elif object['label'] == 'traffic sign':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(153, 153, 153, 255))
        elif object['label'] == 'traffic light':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(153, 153, 153, 255))
            """ NATURE """
        elif object['label'] == 'vegetation':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(244, 35, 232, 255))
        elif object['label'] == 'terrain':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(244, 35, 232, 255))
            """ SKY """
        elif object['label'] == 'sky':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(70, 70, 70, 255))
            """ VOID """
        elif object['label'] == 'ground':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(70, 130, 180, 255))
        elif object['label'] == 'dynamic':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(70, 130, 180, 255))
        elif object['label'] == 'static':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(70, 130, 180, 255)) 
        else : pass
    img.save(f'./masks/{file_path}.png')

# %% [markdown]
# # Préparation Data val

# %%
for i in range(len(df_val)):
    img = Image.open(df_val['Image_Path'][i])
    file_path = df_val['Index'][i]
    img.save(f'./images_val/{file_path}.png')

# %%
for i in range(len(df_val)):
    path_JSON = df_val['Target_Path'][i]
    file_path = df_val['Index'][i]
    with open(path_JSON, 'r') as f:
        json_file = json.load(f)
    img = Image.new("RGB", (json_file['imgWidth'], json_file['imgHeight']), "black")
    draw = ImageDraw.Draw(img)

    for object in json_file['objects']:
        polygon_annotation = []
        """ VEHICLE """
        if object['label'] == 'car':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'truck':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'bus':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'on rails':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'motorcycle':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'bicycle':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'caravan':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
        elif object['label'] == 'trailer':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(250, 170, 30, 255))
            """ FLAT """
        elif object['label'] == 'road':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(0, 0, 142, 255))
        elif object['label'] == 'sidewalk':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(0, 0, 142, 255))
        elif object['label'] == 'parking':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(0, 0, 142, 255))
        elif object['label'] == 'rail track':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(0, 0, 142, 255))
            """ HUMAN """
        elif object['label'] == 'person':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(102, 102, 156, 255))
        elif object['label'] == 'rider':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(102, 102, 156, 255))
            """ CONSTRUCTION """
        elif object['label'] == 'building':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'wall':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'fence':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'guard rail':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'bridge':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
        elif object['label'] == 'tunnel':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(220, 20, 60, 255))
            """ OBJECT """
        elif object['label'] == 'pole':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(153, 153, 153, 255))
        elif object['label'] == 'pole group':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(153, 153, 153, 255))
        elif object['label'] == 'traffic sign':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(153, 153, 153, 255))
        elif object['label'] == 'traffic light':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(153, 153, 153, 255))
            """ NATURE """
        elif object['label'] == 'vegetation':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(244, 35, 232, 255))
        elif object['label'] == 'terrain':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(244, 35, 232, 255))
            """ SKY """
        elif object['label'] == 'sky':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(70, 70, 70, 255))
            """ VOID """
        elif object['label'] == 'ground':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(70, 130, 180, 255))
        elif object['label'] == 'dynamic':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(70, 130, 180, 255))
        elif object['label'] == 'static':
            for x, y in object['polygon']:
                polygon_annotation.append((x, y))
            draw.polygon(polygon_annotation, fill=(70, 130, 180, 255)) 
        else : pass
    img.save(f'./masks_val/{file_path}.png')

# %% [markdown]
# # Partie entraînement local - Récupération image local

# %%
import numpy as np
import json
from PIL import Image, ImageDraw
import os
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
train_image_dir = "./images"

image_paths_train = []

for i in os.listdir(train_image_dir):
    folder_path = os.path.join(train_image_dir, i)
    if i != '.DS_Store':
        image_paths_train.append(folder_path)

# %%
train_label_dir = "./masks"

label_paths_train = []

for i in os.listdir(train_label_dir):
    folder_path = os.path.join(train_label_dir, i)
    if i != '.DS_Store':
        label_paths_train.append(folder_path)

# %%
df_image_paths_train = pd.DataFrame({"Index": "", "Image_Path": image_paths_train})
df_label_paths_train = pd.DataFrame({"Index": "", "Target_Path": label_paths_train})

# %%
print(len(df_image_paths_train))# X
print(len(df_label_paths_train))# y
# Out:
# 174
# 174

# %%
index_tab = []
for el in df_image_paths_train['Image_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_image_paths_train['Index'] = index_tab

# %%
index_tab = []
for el in df_label_paths_train['Target_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_label_paths_train['Index'] = index_tab

# %%
df_train = pd.merge(df_image_paths_train, df_label_paths_train, on='Index', how='left')
df_train
# Out:
#                     Index                         Image_Path  \
# 0    aachen_000008_000019  ./images/aachen_000008_000019.png
# 1    aachen_000149_000019  ./images/aachen_000149_000019.png
# 2    aachen_000095_000019  ./images/aachen_000095_000019.png
# 3    aachen_000014_000019  ./images/aachen_000014_000019.png
# 4    aachen_000023_000019  ./images/aachen_000023_000019.png
# ..                    ...                                ...
# 169  aachen_000053_000019  ./images/aachen_000053_000019.png
# 170  aachen_000112_000019  ./images/aachen_000112_000019.png
# 171  aachen_000125_000019  ./images/aachen_000125_000019.png
# 172  aachen_000006_000019  ./images/aachen_000006_000019.png
# 173  aachen_000031_000019  ./images/aachen_000031_000019.png
#
#                           Target_Path
# 0    ./masks/aachen_000008_000019.png
# 1    ./masks/aachen_000149_000019.png
# 2    ./masks/aachen_000095_000019.png
# 3    ./masks/aachen_000014_000019.png
# 4    ./masks/aachen_000023_000019.png
# ..                                ...
# 169  ./masks/aachen_000053_000019.png
# 170  ./masks/aachen_000112_000019.png
# 171  ./masks/aachen_000125_000019.png
# 172  ./masks/aachen_000006_000019.png
# 173  ./masks/aachen_000031_000019.png
#
# [174 rows x 3 columns]

# %%
val_image_dir = "./images_val"

image_paths_val = []

for i in os.listdir(val_image_dir):
    folder_path = os.path.join(val_image_dir, i)
    if i != '.DS_Store':
        image_paths_val.append(folder_path)

# %%
val_label_dir = "./masks_val"

label_paths_val = []

for i in os.listdir(val_label_dir):
    folder_path = os.path.join(val_label_dir, i)
    if i != '.DS_Store':
        label_paths_val.append(folder_path)

# %%
df_image_paths_val = pd.DataFrame({"Index": "", "Image_Path": image_paths_val})
df_label_paths_val = pd.DataFrame({"Index": "", "Target_Path": label_paths_val})

# %%
print(len(df_image_paths_val))# X
print(len(df_label_paths_val))# y
# Out:
# 36
# 36

# %%
index_tab = []
for el in df_image_paths_val['Image_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_image_paths_val['Index'] = index_tab

# %%
index_tab = []
for el in df_label_paths_val['Target_Path']:
    file_name = os.path.splitext(os.path.basename(el))[0]
    index_tab.append(file_name)
df_label_paths_val['Index'] = index_tab

# %%
df_val = pd.merge(df_image_paths_val, df_label_paths_val, on='Index', how='left')
df_val
# Out:
#                       Index                                Image_Path  \
# 0   frankfurt_000001_013496  ./images_val/frankfurt_000001_013496.png
# 1   frankfurt_000001_072295  ./images_val/frankfurt_000001_072295.png
# 2   frankfurt_000001_065850  ./images_val/frankfurt_000001_065850.png
# 3   frankfurt_000001_062250  ./images_val/frankfurt_000001_062250.png
# 4   frankfurt_000001_054640  ./images_val/frankfurt_000001_054640.png
# 5   frankfurt_000001_051516  ./images_val/frankfurt_000001_051516.png
# 6   frankfurt_000000_018797  ./images_val/frankfurt_000000_018797.png
# 7   frankfurt_000001_042384  ./images_val/frankfurt_000001_042384.png
# 8   frankfurt_000001_008688  ./images_val/frankfurt_000001_008688.png
# 9   frankfurt_000001_054219  ./images_val/frankfurt_000001_054219.png
# 10  frankfurt_000001_032942  ./images_val/frankfurt_000001_032942.png
# 11  frankfurt_000001_050686  ./images_val/frankfurt_000001_050686.png
# 12  frankfurt_000000_016286  ./images_val/frankfurt_000000_016286.png
# 13  frankfurt_000000_015389  ./images_val/frankfurt_000000_015389.png
# 14  frankfurt_000001_042733  ./images_val/frankfurt_000001_042733.png
# 15  frankfurt_000000_009969  ./images_val/frankfurt_000000_009969.png
# 16  frankfurt_000001_035144  ./images_val/frankfurt_000001_035144.png
# 17  frankfurt_000000_013067  ./images_val/frankfurt_000000_013067.png
# 18  frankfurt_000001_033655  ./images_val/frankfurt_000001_033655.png
# 19  frankfurt_000000_007365  ./images_val/frankfurt_000000_007365.png
# 20  frankfurt_000001_075984  ./images_val/frankfurt_000001_075984.png
# 21  frankfurt_000001_073243  ./images_val/frankfurt_000001_073243.png
# 22  frankfurt_000001_063045  ./images_val/frankfurt_000001_063045.png
# 23  frankfurt_000001_077434  ./images_val/frankfurt_000001_077434.png
# 24  frankfurt_000001_017101  ./images_val/frankfurt_000001_017101.png
# 25  frankfurt_000001_073911  ./images_val/frankfurt_000001_073911.png
# 26  frankfurt_000000_000576  ./images_val/frankfurt_000000_000576.png
# 27  frankfurt_000001_003588  ./images_val/frankfurt_000001_003588.png
# 28  frankfurt_000001_038245  ./images_val/frankfurt_000001_038245.png
# 29  frankfurt_000000_004617  ./images_val/frankfurt_000000_004617.png
# 30  frankfurt_000000_001751  ./images_val/frankfurt_000000_001751.png
# 31  frankfurt_000001_031416  ./images_val/frankfurt_000001_031416.png
# 32  frankfurt_000001_080391  ./images_val/frankfurt_000001_080391.png
# 33  frankfurt_000001_025512  ./images_val/frankfurt_000001_025512.png
# 34  frankfurt_000001_067735  ./images_val/frankfurt_000001_067735.png
# 35  frankfurt_000001_046504  ./images_val/frankfurt_000001_046504.png
#
#                                 Target_Path
# 0   ./masks_val/frankfurt_000001_013496.png
# 1   ./masks_val/frankfurt_000001_072295.png
# 2   ./masks_val/frankfurt_000001_065850.png
# 3   ./masks_val/frankfurt_000001_062250.png
# 4   ./masks_val/frankfurt_000001_054640.png
# 5   ./masks_val/frankfurt_000001_051516.png
# 6   ./masks_val/frankfurt_000000_018797.png
# 7   ./masks_val/frankfurt_000001_042384.png
# 8   ./masks_val/frankfurt_000001_008688.png
# 9   ./masks_val/frankfurt_000001_054219.png
# 10  ./masks_val/frankfurt_000001_032942.png
# 11  ./masks_val/frankfurt_000001_050686.png
# 12  ./masks_val/frankfurt_000000_016286.png
# 13  ./masks_val/frankfurt_000000_015389.png
# 14  ./masks_val/frankfurt_000001_042733.png
# 15  ./masks_val/frankfurt_000000_009969.png
# 16  ./masks_val/frankfurt_000001_035144.png
# 17  ./masks_val/frankfurt_000000_013067.png
# 18  ./masks_val/frankfurt_000001_033655.png
# 19  ./masks_val/frankfurt_000000_007365.png
# 20  ./masks_val/frankfurt_000001_075984.png
# 21  ./masks_val/frankfurt_000001_073243.png
# 22  ./masks_val/frankfurt_000001_063045.png
# 23  ./masks_val/frankfurt_000001_077434.png
# 24  ./masks_val/frankfurt_000001_017101.png
# 25  ./masks_val/frankfurt_000001_073911.png
# 26  ./masks_val/frankfurt_000000_000576.png
# 27  ./masks_val/frankfurt_000001_003588.png
# 28  ./masks_val/frankfurt_000001_038245.png
# 29  ./masks_val/frankfurt_000000_004617.png
# 30  ./masks_val/frankfurt_000000_001751.png
# 31  ./masks_val/frankfurt_000001_031416.png
# 32  ./masks_val/frankfurt_000001_080391.png
# 33  ./masks_val/frankfurt_000001_025512.png
# 34  ./masks_val/frankfurt_000001_067735.png
# 35  ./masks_val/frankfurt_000001_046504.png

# %% [markdown]
# # Création modèle

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from keras.losses import SparseCategoricalCrossentropy
import os
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
def unet_model(input_shape, num_classes):
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(conv5)
    drop5 = Dropout(0.5)(conv5)

    # Decoder
    up6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(drop5)
    up6 = concatenate([up6, drop4], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(up6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(conv6)

    up7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
    up7 = concatenate([up7, conv3], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(up7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(conv7)

    up8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
    up8 = concatenate([up8, conv2], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(up8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(conv8)

    up9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
    up9 = concatenate([up9, conv1], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(up9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(conv9)

    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(conv9)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

input_shape = (256, 256, 3)  # Taille d'entrée de l'image
num_classes = 8
model = unet_model(input_shape, num_classes)

# %%
input_shape2 = (256, 256, 3)
imgX = Image.open(df_val['Target_Path'][0])
img_array = img_to_array(imgX.resize(input_shape2[:2], Image.NEAREST))
img_array.shape
# Out:
# (256, 256, 3)

# %%
img_not_array = Image.fromarray(img_array.astype('uint8'))
colors = img_not_array.getcolors(maxcolors=1000000)
num_colors = len(colors)
print(f'Le nombre de couleurs unique est de {num_colors}')
print('--------------------------------------------')
for color in colors:
    print("Couleur :", color[1])
# Out:
# Le nombre de couleurs unique est de 8
# --------------------------------------------
# Couleur : (250, 170, 30)
# Couleur : (0, 0, 142)
# Couleur : (102, 102, 156)
# Couleur : (220, 20, 60)
# Couleur : (153, 153, 153)
# Couleur : (244, 35, 232)
# Couleur : (70, 70, 70)
# Couleur : (70, 130, 180)

# %%
input_shape2 = (256, 256, 3)

def load_data(df):
    images_tab = []
    masks_tab = []
    for i in range(len(df)):
        image_path = df['Image_Path'][i]
        mask_path = df['Target_Path'][i]
        image = img_to_array(Image.open(image_path).convert('RGB').resize(input_shape[:2]))
        images_tab.append(image)

        img_array = img_to_array(Image.open(mask_path).resize(input_shape2[:2], Image.NEAREST))
        for x in range(img_array.shape[0]):
            for y in range(img_array.shape[1]):
                if (img_array[x, y] == [250, 170, 30]).all():
                    img_array[x, y] = 0
                elif (img_array[x, y] == [0, 0, 142]).all():
                    img_array[x, y] = 1
                elif (img_array[x, y] == [102, 102, 156]).all():
                    img_array[x, y] = 2
                elif (img_array[x, y] == [220, 20, 60]).all():
                    img_array[x, y] = 3
                elif (img_array[x, y] == [153, 153, 153]).all():
                    img_array[x, y] = 4
                elif (img_array[x, y] == [244, 35, 232]).all():
                    img_array[x, y] = 5
                elif (img_array[x, y] == [70, 70, 70]).all():
                    img_array[x, y] = 6
                elif (img_array[x, y] == [70, 130, 180]).all():
                    img_array[x, y] = 7
        img_transformed = img_array[:, :, 0:1]
        mask = img_transformed
        masks_tab.append(mask)

    images_tab = np.array(images_tab)
    masks_tab = np.array(masks_tab)
    return images_tab, masks_tab

# %%
images, masks = load_data(df_train)
images_val, masks_val = load_data(df_val)
print("Nombre total d'images chargées:", len(images))
print("Nombre total de masks chargées:", len(masks))
print("Nombre total d'images de validation chargées:", len(images_val))
print("Nombre total de masks de validation chargées:", len(masks_val))
# Out:
# Nombre total d'images chargées: 174
# Nombre total de masks chargées: 174
# Nombre total d'images de validation chargées: 36
# Nombre total de masks de validation chargées: 36

# %%
X_train = images 
X_val = images_val
y_train = masks
y_val = masks_val
#y_train = to_categorical(masks, 8)
#y_val = to_categorical(masks_val, 8)

# %% [markdown]
# # Test d'affichage

# %%
first_image_array = X_train[0].copy()
first_image_array = np.uint8(first_image_array)
pil_image = Image.fromarray(first_image_array)
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
first_mask_array = y_train[0].copy()
first_mask_array = np.uint8(first_mask_array)
transformed_array = np.repeat(first_mask_array, 3, axis=2)
print(transformed_array.shape)
# Out:
# (256, 256, 3)

# %%
for x in range(transformed_array.shape[0]):
    for y in range(transformed_array.shape[1]):
        if (transformed_array[x, y] == [0, 0, 0]).all():
            transformed_array[x, y] = [250, 170, 30]
        elif (transformed_array[x, y] == [1, 1, 1]).all():
            transformed_array[x, y] = [0, 0, 142]
        elif (transformed_array[x, y] == [2, 2, 2]).all():
            transformed_array[x, y] = [102, 102, 156]
        elif (transformed_array[x, y] == [3, 3, 3]).all():
            transformed_array[x, y] = [220, 20, 60]
        elif (transformed_array[x, y] == [4, 4, 4]).all():
            transformed_array[x, y] = [153, 153, 153]
        elif (transformed_array[x, y] == [5, 5, 5]).all():
            transformed_array[x, y] = [244, 35, 232]
        elif (transformed_array[x, y] == [6, 6, 6]).all():
            transformed_array[x, y] = [70, 70, 70]
        elif (transformed_array[x, y] == [7, 7, 7]).all():
            transformed_array[x, y] = [70, 130, 180]

# %%
pil_mask = Image.fromarray(transformed_array)
pil_mask
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
X_train = X_train.astype('float32') / 255.
X_val = X_val.astype('float32') / 255.

# %%
model = unet_model(input_shape, num_classes)

model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=5, verbose=1)
# Out:
# Epoch 1/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 463s 76s/step - accuracy: 0.4450 - loss: 2.1238 - val_accuracy: 0.4747 - val_loss: 1.8690
# Epoch 2/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 439s 73s/step - accuracy: 0.4100 - loss: 2.3305 - val_accuracy: 0.4747 - val_loss: 1.8381
# Epoch 3/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 447s 72s/step - accuracy: 0.4447 - loss: 1.8606 - val_accuracy: 0.4747 - val_loss: 1.7429
# Epoch 4/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 446s 75s/step - accuracy: 0.4493 - loss: 1.7652 - val_accuracy: 0.4747 - val_loss: 1.6938
# Epoch 5/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 407s 67s/step - accuracy: 0.4394 - loss: 1.6996 - val_accuracy: 0.4747 - val_loss: 1.7032

# %%
from tensorflow.keras.models import save_model

save_model(model, 'model_X.keras')
